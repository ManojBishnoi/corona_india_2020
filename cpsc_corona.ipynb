# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %%
df=pd.read_html('https://docs.google.com/spreadsheets/d/e/2PACX-1vSc_2y5N0I67wDU38DjDh35IZSIS30rQf7_NYZhtYYGU1jJYT6_kDx4YpF-qw0LSlGsBYP8pqM_a1Pd/pubhtml#')

# %%
masterdata=pd.DataFrame(df[0])

# %%
masterdata
# Out:
#       Unnamed: 0      Unnamed: 1            Unnamed: 2      Unnamed: 3  \
# 0            1.0  Patient Number  State Patient Number  Date Announced
# 1            NaN             NaN                   NaN             NaN
# 2            2.0               1              KL-TS-P1      30/01/2020
# 3            3.0               2              KL-AL-P1      02/02/2020
# 4            4.0               3              KL-KS-P1      03/02/2020
# ...          ...             ...                   ...             ...
# 1069      1069.0            1069                   NaN             NaN
# 1070      1070.0            1070                   NaN             NaN
# 1071      1071.0            1071                   NaN             NaN
# 1072      1072.0            1072                   NaN             NaN
# 1073      1073.0            1073                   NaN             NaN
#
#                 Unnamed: 4   Unnamed: 5 Unnamed: 6     Unnamed: 7  \
# 0     Estimated Onset Date  Age Bracket     Gender  Detected City
# 1                      NaN          NaN        NaN            NaN
# 2                      NaN           20          F       Thrissur
# 3                      NaN          NaN        NaN      Alappuzha
# 4                      NaN          NaN        NaN      Kasaragod
# ...                    ...          ...        ...            ...
# 1069                   NaN          NaN        NaN            NaN
# 1070                   NaN          NaN        NaN            NaN
# 1071                   NaN          NaN        NaN            NaN
# 1072                   NaN          NaN        NaN            NaN
# 1073                   NaN          NaN        NaN            NaN
#
#              Unnamed: 8      Unnamed: 9  ...  \
# 0     Detected District  Detected State  ...
# 1                   NaN             NaN  ...
# 2              Thrissur          Kerala  ...
# 3             Alappuzha          Kerala  ...
# 4             Kasaragod          Kerala  ...
# ...                 ...             ...  ...
# 1069                NaN             NaN  ...
# 1070                NaN             NaN  ...
# 1071                NaN             NaN  ...
# 1072                NaN             NaN  ...
# 1073                NaN             NaN  ...
#
#                                             Unnamed: 16  \
# 0                                              Source_2
# 1                                                   NaN
# 2     https://weather.com/en-IN/india/news/news/2020...
# 3     https://weather.com/en-IN/india/news/news/2020...
# 4     https://twitter.com/ANI/status/122422148580539...
# ...                                                 ...
# 1069                                                NaN
# 1070                                                NaN
# 1071                                                NaN
# 1072                                                NaN
# 1073                                                NaN
#
#                                             Unnamed: 17         Unnamed: 18  \
# 0                                              Source_3        Backup Notes
# 1                                                   NaN                 NaN
# 2     https://weather.com/en-IN/india/news/news/2020...  Student from Wuhan
# 3                                                   NaN  Student from Wuhan
# 4     https://weather.com/en-IN/india/news/news/2020...  Student from Wuhan
# ...                                                 ...                 ...
# 1069                                                NaN                 NaN
# 1070                                                NaN                 NaN
# 1071                                                NaN                 NaN
# 1072                                                NaN                 NaN
# 1073                                                NaN                 NaN
#
#      Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 1069         NaN         NaN         NaN         NaN         NaN         NaN
# 1070         NaN         NaN         NaN         NaN         NaN         NaN
# 1071         NaN         NaN         NaN         NaN         NaN         NaN
# 1072         NaN         NaN         NaN         NaN         NaN         NaN
# 1073         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Unnamed: 25
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 1069          NaN
# 1070          NaN
# 1071          NaN
# 1072          NaN
# 1073          NaN
#
# [1074 rows x 26 columns]

# %%
# checking number of rows and columns 
print("Our dataset has " + color.BOLD + str(masterdata1.shape[0]) +  color.END + " rows & " + color.BOLD + str(masterdata1.shape[1]) + " columns")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-02016c35984e> in <module>
#       1 # checking number of rows and columns
# ----> 2 print("Our dataset has " + color.BOLD + str(masterdata1.shape[0]) +  color.END + " rows & " + color.BOLD + str(masterdata1.shape[1]) + " columns")
#
# NameError: name 'masterdata1' is not defined

# %%
header=masterdata.iloc[0]
masterdata=masterdata[1:]

# %%
masterdata.columns=header

# %%
masterdata=masterdata.drop(masterdata.index[0])

# %%
masterdata.columns
# Out:
# Index([                                        1.0,
#                                   'Patient Number',
#                             'State Patient Number',
#                                   'Date Announced',
#                             'Estimated Onset Date',
#                                      'Age Bracket',
#                                           'Gender',
#                                    'Detected City',
#                                'Detected District',
#                                   'Detected State',
#                                   'Current Status',
#                                            'Notes',
#        'Contracted from which Patient (Suspected)',
#                                      'Nationality',
#                               'Status Change Date',
#                                         'Source_1',
#                                         'Source_2',
#                                         'Source_3',
#                                     'Backup Notes',
#                                                nan,
#                                                nan,
#                                                nan,
#                                                nan,
#                                                nan,
#                                                nan,
#                                                nan],
#       dtype='object', name=0)

# %%
masterdata.drop(masterdata.columns[[0,7,8,19,20,21,22,23,24,25]], axis = 1,inplace=True)

# %%
masterdata=masterdata.rename(columns={masterdata.columns[8]:'Travelled From'})

# %%
masterdata
# Out:
# 0    Patient Number State Patient Number Date Announced Estimated Onset Date  \
# 2                 1             KL-TS-P1     30/01/2020                  NaN
# 3                 2             KL-AL-P1     02/02/2020                  NaN
# 4                 3             KL-KS-P1     03/02/2020                  NaN
# 5                 4                DL-P1     02/03/2020                  NaN
# 6                 5                TS-P1     02/03/2020                  NaN
# ...             ...                  ...            ...                  ...
# 1069           1069                  NaN            NaN                  NaN
# 1070           1070                  NaN            NaN                  NaN
# 1071           1071                  NaN            NaN                  NaN
# 1072           1072                  NaN            NaN                  NaN
# 1073           1073                  NaN            NaN                  NaN
#
# 0    Age Bracket Gender Detected State Current Status  \
# 2             20      F         Kerala      Recovered
# 3            NaN    NaN         Kerala      Recovered
# 4            NaN    NaN         Kerala      Recovered
# 5             45      M          Delhi      Recovered
# 6             24      M      Telangana      Recovered
# ...          ...    ...            ...            ...
# 1069         NaN    NaN            NaN            NaN
# 1070         NaN    NaN            NaN            NaN
# 1071         NaN    NaN            NaN            NaN
# 1072         NaN    NaN            NaN            NaN
# 1073         NaN    NaN            NaN            NaN
#
# 0                    Travelled From Contracted from which Patient (Suspected)  \
# 2              Travelled from Wuhan                                       NaN
# 3              Travelled from Wuhan                                       NaN
# 4              Travelled from Wuhan                                       NaN
# 5     Travelled from Austria, Italy                                       NaN
# 6                               NaN                                       NaN
# ...                             ...                                       ...
# 1069                            NaN                                       NaN
# 1070                            NaN                                       NaN
# 1071                            NaN                                       NaN
# 1072                            NaN                                       NaN
# 1073                            NaN                                       NaN
#
# 0    Nationality Status Change Date  \
# 2          India         14/02/2020
# 3          India         14/02/2020
# 4          India         14/02/2020
# 5          India         15/03/2020
# 6          India         02/03/2020
# ...          ...                ...
# 1069         NaN                NaN
# 1070         NaN                NaN
# 1071         NaN                NaN
# 1072         NaN                NaN
# 1073         NaN                NaN
#
# 0                                              Source_1  \
# 2     https://twitter.com/vijayanpinarayi/status/122...
# 3     https://www.indiatoday.in/india/story/kerala-r...
# 4     https://www.indiatoday.in/india/story/kerala-n...
# 5     https://www.indiatoday.in/india/story/not-a-ja...
# 6     https://indianexpress.com/article/india/corona...
# ...                                                 ...
# 1069                                                NaN
# 1070                                                NaN
# 1071                                                NaN
# 1072                                                NaN
# 1073                                                NaN
#
# 0                                              Source_2  \
# 2     https://weather.com/en-IN/india/news/news/2020...
# 3     https://weather.com/en-IN/india/news/news/2020...
# 4     https://twitter.com/ANI/status/122422148580539...
# 5     https://economictimes.indiatimes.com/news/poli...
# 6     https://www.indiatoday.in/india/story/coronavi...
# ...                                                 ...
# 1069                                                NaN
# 1070                                                NaN
# 1071                                                NaN
# 1072                                                NaN
# 1073                                                NaN
#
# 0                                              Source_3  \
# 2     https://weather.com/en-IN/india/news/news/2020...
# 3                                                   NaN
# 4     https://weather.com/en-IN/india/news/news/2020...
# 5                                                   NaN
# 6     https://www.thehindu.com/news/national/coronav...
# ...                                                 ...
# 1069                                                NaN
# 1070                                                NaN
# 1071                                                NaN
# 1072                                                NaN
# 1073                                                NaN
#
# 0                                   Backup Notes
# 2                             Student from Wuhan
# 3                             Student from Wuhan
# 4                             Student from Wuhan
# 5            Travel history to Italy and Austria
# 6     Travel history to Dubai, Singapore contact
# ...                                          ...
# 1069                                         NaN
# 1070                                         NaN
# 1071                                         NaN
# 1072                                         NaN
# 1073                                         NaN
#
# [1072 rows x 16 columns]

# %%
masterdata.isna().sum()
# Out:
# 0
# Patient Number                                  0
# State Patient Number                          827
# Date Announced                                 14
# Estimated Onset Date                         1072
# Age Bracket                                   599
# Gender                                        551
# Detected State                                 22
# Current Status                                 22
# Travelled From                                 28
# Contracted from which Patient (Suspected)     829
# Nationality                                   666
# Status Change Date                             17
# Source_1                                       34
# Source_2                                      542
# Source_3                                      954
# Backup Notes                                  711
# dtype: int64

# %%
masterdata.drop(['Estimated Onset Date'],axis=1,inplace=True)

# %%
masterdata.isna().sum()
# Out:
# 0
# Patient Number                                 0
# State Patient Number                         827
# Date Announced                                14
# Age Bracket                                  599
# Gender                                       551
# Detected State                                22
# Current Status                                22
# Travelled From                                28
# Contracted from which Patient (Suspected)    829
# Nationality                                  666
# Status Change Date                            17
# Source_1                                      34
# Source_2                                     542
# Source_3                                     954
# Backup Notes                                 711
# dtype: int64

# %%
pd.set_option('display.max_columns',None)

# %%
masterdata
# Out:
# 0    Patient Number State Patient Number Date Announced Age Bracket Gender  \
# 2                 1             KL-TS-P1     30/01/2020          20      F
# 3                 2             KL-AL-P1     02/02/2020         NaN    NaN
# 4                 3             KL-KS-P1     03/02/2020         NaN    NaN
# 5                 4                DL-P1     02/03/2020          45      M
# 6                 5                TS-P1     02/03/2020          24      M
# ...             ...                  ...            ...         ...    ...
# 1069           1069                  NaN            NaN         NaN    NaN
# 1070           1070                  NaN            NaN         NaN    NaN
# 1071           1071                  NaN            NaN         NaN    NaN
# 1072           1072                  NaN            NaN         NaN    NaN
# 1073           1073                  NaN            NaN         NaN    NaN
#
# 0    Detected State Current Status                 Travelled From  \
# 2            Kerala      Recovered           Travelled from Wuhan
# 3            Kerala      Recovered           Travelled from Wuhan
# 4            Kerala      Recovered           Travelled from Wuhan
# 5             Delhi      Recovered  Travelled from Austria, Italy
# 6         Telangana      Recovered                            NaN
# ...             ...            ...                            ...
# 1069            NaN            NaN                            NaN
# 1070            NaN            NaN                            NaN
# 1071            NaN            NaN                            NaN
# 1072            NaN            NaN                            NaN
# 1073            NaN            NaN                            NaN
#
# 0    Contracted from which Patient (Suspected) Nationality Status Change Date  \
# 2                                          NaN       India         14/02/2020
# 3                                          NaN       India         14/02/2020
# 4                                          NaN       India         14/02/2020
# 5                                          NaN       India         15/03/2020
# 6                                          NaN       India         02/03/2020
# ...                                        ...         ...                ...
# 1069                                       NaN         NaN                NaN
# 1070                                       NaN         NaN                NaN
# 1071                                       NaN         NaN                NaN
# 1072                                       NaN         NaN                NaN
# 1073                                       NaN         NaN                NaN
#
# 0                                              Source_1  \
# 2     https://twitter.com/vijayanpinarayi/status/122...
# 3     https://www.indiatoday.in/india/story/kerala-r...
# 4     https://www.indiatoday.in/india/story/kerala-n...
# 5     https://www.indiatoday.in/india/story/not-a-ja...
# 6     https://indianexpress.com/article/india/corona...
# ...                                                 ...
# 1069                                                NaN
# 1070                                                NaN
# 1071                                                NaN
# 1072                                                NaN
# 1073                                                NaN
#
# 0                                              Source_2  \
# 2     https://weather.com/en-IN/india/news/news/2020...
# 3     https://weather.com/en-IN/india/news/news/2020...
# 4     https://twitter.com/ANI/status/122422148580539...
# 5     https://economictimes.indiatimes.com/news/poli...
# 6     https://www.indiatoday.in/india/story/coronavi...
# ...                                                 ...
# 1069                                                NaN
# 1070                                                NaN
# 1071                                                NaN
# 1072                                                NaN
# 1073                                                NaN
#
# 0                                              Source_3  \
# 2     https://weather.com/en-IN/india/news/news/2020...
# 3                                                   NaN
# 4     https://weather.com/en-IN/india/news/news/2020...
# 5                                                   NaN
# 6     https://www.thehindu.com/news/national/coronav...
# ...                                                 ...
# 1069                                                NaN
# 1070                                                NaN
# 1071                                                NaN
# 1072                                                NaN
# 1073                                                NaN
#
# 0                                   Backup Notes
# 2                             Student from Wuhan
# 3                             Student from Wuhan
# 4                             Student from Wuhan
# 5            Travel history to Italy and Austria
# 6     Travel history to Dubai, Singapore contact
# ...                                          ...
# 1069                                         NaN
# 1070                                         NaN
# 1071                                         NaN
# 1072                                         NaN
# 1073                                         NaN
#
# [1072 rows x 15 columns]

# %%
list_age=[]

# %%
list_age=list(masterdata['Age Bracket'])

# %%
list_age1=list(filter(lambda x: str(x) != 'nan', list_age))

# %%
list_age1
# Out:
# ['20',
#  '45',
#  '24',
#  '69',
#  '55',
#  '55',
#  '55',
#  '55',
#  '55',
#  '55',
#  '55',
#  '55',
#  '55',
#  '55',
#  '55',
#  '55',
#  '55',
#  '55',
#  '70',
#  '27',
#  '59',
#  '65',
#  '75',
#  '45',
#  '24',
#  '54',
#  '53',
#  '65',
#  '61',
#  '25',
#  '63',
#  '3',
#  '48',
#  '40',
#  '13',
#  '96',
#  '89',
#  '3',
#  '85',
#  '46',
#  '70',
#  '68',
#  '27',
#  '69',
#  '26',
#  '76',
#  '65',
#  '45',
#  '33',
#  '33',
#  '27',
#  '37',
#  '59',
#  '43',
#  '21',
#  '24',
#  '59',
#  '46',
#  '32',
#  '45',
#  '47',
#  '42',
#  '33',
#  '3',
#  '44',
#  '51',
#  '31',
#  '29',
#  '20',
#  '67',
#  '63',
#  '49',
#  '26',
#  '68',
#  '52',
#  '21',
#  '18',
#  '34',
#  '28',
#  '25',
#  '22',
#  '56',
#  '25',
#  '44',
#  '20',
#  '68',
#  '35',
#  '21',
#  '50',
#  '67',
#  '33',
#  '30',
#  '3',
#  '38',
#  '23',
#  '22',
#  '49',
#  '35',
#  '24',
#  '24',
#  '21',
#  '70',
#  '47',
#  '32',
#  '21',
#  '51',
#  '19',
#  '65',
#  '22',
#  '22',
#  '32',
#  '22',
#  '69',
#  '58',
#  '24',
#  '38',
#  '20',
#  '22',
#  '34',
#  '47',
#  '37',
#  '35',
#  '20',
#  '41',
#  '18',
#  '69',
#  '27',
#  '26',
#  '52',
#  '21',
#  '52',
#  '27',
#  '2',
#  '63',
#  '32',
#  '59',
#  '45',
#  '22',
#  '24',
#  '27',
#  '60',
#  '32',
#  '53',
#  '20',
#  '23',
#  '42',
#  '74',
#  '28',
#  '59',
#  '63',
#  '41',
#  '24',
#  '26',
#  '32',
#  '38',
#  '67',
#  '26',
#  '53',
#  '39',
#  '19',
#  '35',
#  '33',
#  '69',
#  '75',
#  '65',
#  '35',
#  '34',
#  '45',
#  '40',
#  '17',
#  '36',
#  '60',
#  '54',
#  '21',
#  '35',
#  '23',
#  '57',
#  '59',
#  '22',
#  '24',
#  '31',
#  '30',
#  '33',
#  '32',
#  '30',
#  '21',
#  '60',
#  '64',
#  '35',
#  '25',
#  '38',
#  '24',
#  '81',
#  '26',
#  '58',
#  '27',
#  '32',
#  '41',
#  '33',
#  '26',
#  '34',
#  '23',
#  '23',
#  '50',
#  '22',
#  '32',
#  '24',
#  '41',
#  '27',
#  '61',
#  '21',
#  '64',
#  '36',
#  '27',
#  '51',
#  '37',
#  '62',
#  '53',
#  '64',
#  '43',
#  '49',
#  '36',
#  '46',
#  '45',
#  '58',
#  '57',
#  '27',
#  '29',
#  '24',
#  '33',
#  '49',
#  '46',
#  '61',
#  '85',
#  '21',
#  '30',
#  '23',
#  '21',
#  '20',
#  '25',
#  '56',
#  '32',
#  '49',
#  '24',
#  '30',
#  '31',
#  '41',
#  '34',
#  '40',
#  '37',
#  '47',
#  '34',
#  '21',
#  '50',
#  '32',
#  '27',
#  '33',
#  '32',
#  '27',
#  '34',
#  '52',
#  '26',
#  '61',
#  '56',
#  '38',
#  '41',
#  '30',
#  '24',
#  '60',
#  '22',
#  '38',
#  '45',
#  '45',
#  '69',
#  '2',
#  '25',
#  '25',
#  '48',
#  '54',
#  '24',
#  '35',
#  '41',
#  '23',
#  '32',
#  '40',
#  '65',
#  '56',
#  '65',
#  '53',
#  '54',
#  '58',
#  '74',
#  '52',
#  '25',
#  '49',
#  '39',
#  '61',
#  '56',
#  '47',
#  '55',
#  '65',
#  '57',
#  '47',
#  '57',
#  '70',
#  '23',
#  '25',
#  '65',
#  '55',
#  '25',
#  '64',
#  '36',
#  '75',
#  '57',
#  '65',
#  '36',
#  '50',
#  '57',
#  '27',
#  '39',
#  '38',
#  '63',
#  '34',
#  '21',
#  '22',
#  '23',
#  '37',
#  '37',
#  '63',
#  '59',
#  '26',
#  '26',
#  '63',
#  '69',
#  '9',
#  '7',
#  '55',
#  '31',
#  '26',
#  '23',
#  '24',
#  '43',
#  '3',
#  '22',
#  '18',
#  '26',
#  '63',
#  '52',
#  '25',
#  '29',
#  '55',
#  '66',
#  '21',
#  '39',
#  '33',
#  '32',
#  '40',
#  '12',
#  '49',
#  '36',
#  '41',
#  '45',
#  '35',
#  '35',
#  '70',
#  '64',
#  '45',
#  '42',
#  '21',
#  '24',
#  '7',
#  '1',
#  '37',
#  '38',
#  '26',
#  '49',
#  '39',
#  '36',
#  '32',
#  '21',
#  '24',
#  '65',
#  '20',
#  '29',
#  '60',
#  '45',
#  '37',
#  '53',
#  '54',
#  '35',
#  '22',
#  '44',
#  '42',
#  '46',
#  '23',
#  '25',
#  '1',
#  '20',
#  '25',
#  '35',
#  '60',
#  '33',
#  '22',
#  '42',
#  '41',
#  '53',
#  '18',
#  '14',
#  '23',
#  '64',
#  '18',
#  '21',
#  '11',
#  '27',
#  '45',
#  '6',
#  '1',
#  '73',
#  '61',
#  '39',
#  '45',
#  '22',
#  '50',
#  '37',
#  '39',
#  '33',
#  '25',
#  '65',
#  '42',
#  '49',
#  '66',
#  '23',
#  '21',
#  '54',
#  '28',
#  '23',
#  '25',
#  '23',
#  '70',
#  '32',
#  '38',
#  '18',
#  '63',
#  '21',
#  '45',
#  '40',
#  '56',
#  '28-35',
#  '28-35',
#  '28-35',
#  '28-35',
#  '60',
#  '74',
#  '21',
#  '25',
#  '20',
#  '24',
#  '76',
#  '56',
#  '50',
#  '23',
#  '60',
#  '50',
#  '65',
#  '54',
#  '21',
#  '40',
#  '48',
#  '21',
#  '38',
#  '17',
#  '53',
#  '21']

# %%
#basic histogram to check corona virus with the age factor.
fig= plt.figure(1, figsize=(50, 10))
#adding one subplot
ax=fig.add_subplot(111)
plt.hist(list_age1,bins=20, facecolor='orange', edgecolor = 'blue')
# Out:
# (array([51., 45., 23., 39., 15.,  5., 23., 24., 51., 10., 22., 32., 26.,
#         34., 15., 20., 20.,  4.,  7.,  7.]),
#  array([ 0. ,  3.6,  7.2, 10.8, 14.4, 18. , 21.6, 25.2, 28.8, 32.4, 36. ,
#         39.6, 43.2, 46.8, 50.4, 54. , 57.6, 61.2, 64.8, 68.4, 72. ]),
#  <a list of 20 Patch objects>)
